# %% [markdown]
# # Playground on Object detection pstage3

# %% [markdown]
# ## GPU check

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Thu May 13 16:50:03 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# ## Drive mount

# %%
from google.colab import drive 

### 해당 코드 실행 시 colab에서 실행중인 폴더의 /content/drive/My Drive가 구글 드라이브에 연결됨
base_dir = '/content/drive'
drive.mount(base_dir)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## SSH environment setting (optional)

# %%
# !pip install colab-ssh --upgrade
# from colab_ssh import launch_ssh_cloudflared, init_git_cloudflared
# launch_ssh_cloudflared(password="upstage")

# %% [markdown]
# ## working directory setting

# %%
import os
working_directory = os.path.join(base_dir, 'MyDrive/boostcamp/pstage3/code')
# %cd $working_directory
# Out:
# /content/drive/MyDrive/Colab Notebooks/pstage3_object_detection

# %% [markdown]
# ## Library install

# %%
# !pip install -r requirements.txt

# %%
from pycocotools.coco import COCO
from pycocotools.cocoeval import COCOeval
import numpy as np
import cv2
import os

import albumentations as A
from albumentations.pytorch.transforms import ToTensorV2

import torch
# faster rcnn model이 포함된 library
import torchvision

from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

from torch.utils.data import DataLoader, Dataset
import pandas as pd
from tqdm import tqdm

# %% [markdown]
# ## Wandb login for experiments monitoring on the web

# %%
# !wandb login
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %% [markdown]
# ## Test flatform - Command Line Interface

# %% [markdown]
# ### config 파일 path 설정
# --config_path $configX_X_path 로 실행하면 각 config 파일이 적용됨

# %%
config1_1_path = os.path.join(working_directory, 'config1_1.json')

# %%
config1_2_path = os.path.join(working_directory, 'config1_2.json')

# %% [markdown]
# ### train, inference 기능
# train.py : config 파일의 설정에 따라 model을 학습
# inference.py : config 파일에 설정된 saved_model_name.pth 모델을 가져와서 test set에 대해 inference를 수행 -> submission 파일을 생성함

# %%
# train
# !python train.py --from_only_config True --config_path $config1_1_path
# inference making submission file
# !python inference.py --from_only_config True --config_path $config1_1_path

# %% [markdown]
# ### model check 기능
# model에 어떤 module이 있는지, 어떤 layer가 얼마나 자원을 소비하는지 확인

# %%
# !python model_check.py --from_only_config True --config_path $config1_1_path

# %% [markdown]
# ### submission 서버 제출 기능
# config 파일에서 submission_user_key를 설정해야 서버로 제출함

# %%
# !python submission.py --from_only_config True --config_path $config1_1_path
